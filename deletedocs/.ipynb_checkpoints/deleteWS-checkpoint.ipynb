# %%
def demorun():
    noclist = []

    nocmemlist = []

    nocadder=[]

    import random

    empbox = []
    sickdates =[['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA']]
    persdates =[['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA']]
    vacdates =[['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA'],['AA']]


    names=[['0','0','0'],['jason','bourne','jabo'],['sara','walker','yvon'],['john','casey','jcas'],['charles','bartowski','chuk'],['jack','bauer','jbow'],['tony','roop','troo'],['greg','cosent','gcos'],['macgregor','jones','macj'],['jalen','hurts','jhur'],['nick','saban','nsab'],['paul','bryant','pbry'],['jim','fallon','jimy'],['conan','brian','cone'],['adam','driver','sith'],['daisy','ridley','drid'],['alec','baldwin','bald'],['steff','tuan','stef'],['chris','rudolf','crud'],['kylo','ren','kyre'],['michael','okeyo','mike'],['michael','donaldson','mdon'],['peter','camp','gunn'],['justine','dean','jusd'],['mary','bailey','bail'],['marc','singer','funk'],['franco','franus','fran'],['chris','velez','slam'],['jose','quizon','chic'],['jumpa','smith','jusm'],['jumpa','jones','jujo'],['thavone','pengpang','peng'],['paul','singh','psin'],['jerry','springer','jspr'],['andrew','jones','anjo'],['cole','henderson','heno'],['george','st.pierre','gstp'],['luc','petty','lpet'],['todd','bryant','tbry'],['robin','banger','bang']]
    areac = ['718','212','917','914']
    stype = ['avenue','road','street']
    borough = ['manhattan','queens','staten island','bronx','brooklyn']
    zipcode = [['10001','10011','10018','10019','10020'],['11354','11355','11356','11357','11358'],['10306','10307','10308','10309','10312'],['10461','10462','10464','10465','10472'],['11201','11205','11215','11217','11231']]




    dept= ['hsk','FD','eng','pbx','sle','acct']
    deptpos =[['*deptmgr','*adeptmgr','*deptsup','hskper','hseman'],['*deptmgr','*adeptmgr','*ntmgr','deptsup','ntaud','fdagnt','bllmn','drmn'],['*deptmgr','*adeptmgr','*deptsup','engnr'],['*deptmgr','*adeptmgr','*deptsup','oprtr'],['*deptmgr','*adeptmgr','*deptsup','res'],['*cntrller','*asscntrller','acctnt']]


    for emp in range(len(names)):
        xsoc = random.randint(100000000,999999999)

        xarea = random.randint(0,3)
        xtelp = random.randint(100,999)
        xtels = random.randint(1000,9999)

        xbuildno = random.randint(1,300)
        xstreetno = random.randint(1,140)
        xstreetype = random.randint(0,2)
        xbtype = random.randint(0,4)
        xziptype = zipcode[xbtype][random.randint(0,4)]

        xmonth = random.randint(1,12)
        xday = random.randint(1,28)
        xyear = random.randint(4,19)

        xdep = random.randint(0,5)
        xdepos = random.randint(0,((len(deptpos[xdep]))-1))

        xpay = random.randint(17,30)

        xsicktk = random.randint(0,6)
        xperstk = random.randint(0,3)
        xvactk = random.randint(0,15)

        names[emp].append(str(xsoc))
        names[emp].append((str(xarea))+(str(xtelp))+(str(xtels)))
        names[emp].append(str(xbuildno)+' '+str(xstreetno)+' '+stype[xstreetype])
        names[emp].append(borough[xbtype])
        names[emp].append('NY')
        names[emp].append(xziptype)
        names[emp].append(xmonth)
        names[emp].append(xday)
        names[emp].append(xyear)
        names[emp].append(dept[xdep])
        names[emp].append(deptpos[xdep][xdepos])
        names[emp].append(str(xpay))
        names[emp].append(str(xpay*40))
        names[emp].append(str((xpay*40)*4))
        names[emp].append(str((xpay*40)*52))
        names[emp].append(str(xsicktk))
        names[emp].append(str(6-xsicktk))
        names[emp].append(str(xperstk))
        names[emp].append(str(3-xperstk))
        names[emp].append(str(xvactk))
        names[emp].append(str(15-xvactk))

        for z in range(xsicktk):
            sickdates[emp].append((str(random.randint(1,12)))+'/'+(str(random.randint(1,28)))+'/19')
        for zz in range(xperstk):
            persdates[emp].append((str(random.randint(1,12)))+'/'+(str(random.randint(1,28)))+'/19')
        for zzz in range(xvactk):
            vacdates[emp].append((str(random.randint(1,12)))+'/'+(str(random.randint(1,28)))+'/19')

    for rost in range(len(names)):
        nocmemlist.append(names[rost])
        nocmemlist.append(sickdates[rost])
        nocmemlist.append(persdates[rost])
        nocmemlist.append(vacdates[rost])

    for rostname in range(len(names)):
        noclist.append(names[rostname][0]+names[rostname][1])

    def listcreate(list,list2,list3,list4,nlist):
    #     this creates txt files from list
        empname = nlist
        with open(f'testdocs\\noclist.night',mode='w')as n:
            for m in range(len(nocadder)):
                n.write(f'{nocadder[m]}\n')    
        with open(f'testdocs\\{empname}D.night',mode='w')as t:
            for k in range(len(list)):
                t.write(f'{list[k]}\n')
        with open(f'testdocs\\{empname}Dsickdates.night',mode='w')as q:
            for r in range(len(list2)):
                q.write(f'{list2[r]}\n')
        with open(f'testdocs\\{empname}Dpersdates.night',mode='w')as s:
            for y in range(len(list3)):
                s.write(f'{list3[y]}\n')
        with open(f'testdocs\\{empname}Dvacdates.night',mode='w')as h:
            for j in range(len(list4)):
                h.write(f'{list4[j]}\n')
        print('files created!')





    def filencrypter(listo):  
    #         from cryptography.fernet import Fernet
    #         key = Fernet.generate_key()
    #         fkey = open('testdocs/niterun/filekeyMain.night','wb')
    #         fkey.write(key)
    #         print (key)
    #     this open encrypter key created by keycreate() as variable

        empname = listo
    #  this is the encryption key opening
        from cryptography.fernet import Fernet
        fkey = open('testdocs/niterun/filekeyMain.night','rb')
        key = fkey.read()
        print (key)
        cipher = Fernet(key)

    #     opens created files to be encrypted and encrypts
        Nocfile= 'testdocs/noclist.night'
        with open(Nocfile,'rb')as e:
            Nocfiletoencrypt = e.read()

            
        Nocencryptedfile = cipher.encrypt(Nocfiletoencrypt) 
        with open(Nocfile,'wb') as ee:
            ee.write(Nocencryptedfile)

    # >>>>>>>>>>>>>>>>>>>>>
        infofile= 'testdocs/'+ empname +'D.night'
        with open(infofile,'rb')as f:
            filetoencrypt = f.read()


        encryptedfile = cipher.encrypt(filetoencrypt) 
        with open(infofile,'wb') as ef:
            ef.write(encryptedfile)


    # >>>>>>>>>>>>>>>>>>>>>          
        sickfile= 'testdocs/'+ empname +'Dsickdates.night'
        with open(sickfile,'rb')as ff:
            sickfiletoencrypt = ff.read()

        sickencryptedfile = cipher.encrypt(sickfiletoencrypt) 
        with open(sickfile,'wb') as eff:
            eff.write(sickencryptedfile)


    # >>>>>>>>>>>>>>>>>>>>>          
        persfile= 'testdocs/'+ empname +'Dpersdates.night'
        with open(persfile,'rb')as fff:
            persfiletoencrypt = fff.read()

        persencryptedfile = cipher.encrypt(persfiletoencrypt) 
        with open(persfile,'wb') as efff:
            efff.write(persencryptedfile)


    # >>>>>>>>>>>>>>>>>>>>>      
        vacfile= 'testdocs/'+ empname +'Dvacdates.night'
        with open(vacfile,'rb')as ffff:
            vacfiletoencrypt = ffff.read()

        vacencryptedfile = cipher.encrypt(vacfiletoencrypt) 
        with open(vacfile,'wb') as effff:
            effff.write(vacencryptedfile)

            
        with open('testdocs/'+ empname +'D.night','rb') as df:
            encryptedfile = df.read()
            print(encryptedfile)
            print('>>>>>>>>>>>>>>>>>>>>>>>')
        decrypted_file = cipher.decrypt(encryptedfile)
        print(decrypted_file.decode())      



    print(noclist)
    print(nocmemlist)
    for x in range(len(noclist)):
    		nocadder.append(noclist[x])
    		listcreate(nocmemlist[(x*4)],nocmemlist[(x*4)+1],nocmemlist[(x*4)+2],nocmemlist[(x*4)+3],noclist[x])
    		filencrypter(noclist[x])
            
demorun()
# Out:
# ['00', 'jasonbourne', 'sarawalker', 'johncasey', 'charlesbartowski', 'jackbauer', 'tonyroop', 'gregcosent', 'macgregorjones', 'jalenhurts', 'nicksaban', 'paulbryant', 'jimfallon', 'conanbrian', 'adamdriver', 'daisyridley', 'alecbaldwin', 'stefftuan', 'chrisrudolf', 'kyloren', 'michaelokeyo', 'michaeldonaldson', 'petercamp', 'justinedean', 'marybailey', 'marcsinger', 'francofranus', 'chrisvelez', 'josequizon', 'jumpasmith', 'jumpajones', 'thavonepengpang', 'paulsingh', 'jerryspringer', 'andrewjones', 'colehenderson', 'georgest.pierre', 'lucpetty', 'toddbryant', 'robinbanger']
# [['0', '0', '0', '762451584', '21456028', '138 112 street', 'bronx', 'NY', '10461', 5, 13, 5, 'eng', '*adeptmgr', '26', '1040', '4160', '54080', '4', '2', '3', '0', '4', '11'], ['AA', '11/23/19', '8/9/19', '7/17/19', '9/12/19'], ['AA', '5/21/19', '8/2/19', '7/11/19'], ['AA', '11/3/19', '7/18/19', '12/10/19', '8/23/19'], ['jason', 'bourne', 'jabo', '209960515', '13478006', '202 49 street', 'brooklyn', 'NY', '11205', 12, 5, 17, 'acct', '*cntrller', '19', '760', '3040', '39520', '5', '1', '3', '0', '4', '11'], ['AA', '3/18/19', '7/8/19', '1/10/19', '6/11/19', '10/16/19'], ['AA', '8/2/19', '7/16/19', '1/4/19'], ['AA', '5/14/19', '1/17/19', '2/19/19', '9/1/19'], ['sara', 'walker', 'yvon', '243042516', '35273896', '46 138 street', 'staten island', 'NY', '10307', 6, 3, 11, 'eng', '*deptmgr', '22', '880', '3520', '45760', '5', '1', '0', '3', '11', '4'], ['AA', '6/24/19', '6/20/19', '6/1/19', '2/9/19', '3/11/19'], ['AA'], ['AA', '6/8/19', '6/3/19', '7/24/19', '12/4/19', '5/1/19', '6/28/19', '5/2/19', '12/7/19', '9/11/19', '10/17/19', '12/17/
# >>>>>>>>>>>>>>>>>>>>>>>
# sara
# walker
# yvon
# 243042516
# 35273896
# 46 138 street
# staten island
# NY
# 10307
# 6
# 3
# 11
# eng
# *deptmgr
# 22
# 880
# 3520
# 45760
# 5
# 1
# 0
# 3
# 11
# 4
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtcMmA-hbGAUvrzKgXy-j1IRFy-6sDc78tMk51j4mm1EmDXXZQk_gJ-udVSDoPcTaZmfkpWu8ppKw-whupaf2d9F1s0ZV7_Qz3NwsBNIeNUb6tKK_efBEUFCxQh8PfC4aXYsJFDJNsPYcWuDqReizqBULvFaOWQnUKnKI7DPu-OFdbT1jrveeba2Q-Ip_5GpBOHgmDQcnB2Hph-eFyKeXSFpVXi5FaO4XE6Wm4oTYXC3tTbhQ9TIxfef5qyYwCSq4s1'
# >>>>>>>>>>>>>>>>>>>>>>>
# john
# casey
# jcas
# 212788883
# 09961636
# 292 136 avenue
# brooklyn
# NY
# 11217
# 8
# 9
# 13
# FD
# fdagnt
# 20
# 800
# 3200
# 41600
# 1
# 5
# 1
# 2
# 3
# 12
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltcfdfki6NvKX33Z_aC3FZRnpC7GYT5WoSdLKKPAoRRurwR8z9JL4H7fICC_PSAZ_-RKLS8Z30qffRTj5JgcRv2L5Mho4XWU0mE0gpIoF5AXF5t6DJlddsOVkmGIqVDBePmkMxZ5Hfr_wMY24CKHe2rW2BGjmqfS0R02sHuhYmBFkKaz5HnLRCqzxqrJxx7YVPpR2U9kWDPnVPtw5a6cH34s4xHkjJW3P_N_pQ-uzQAsxa67t7wpEoGPzx4O2b6baIhG4I3CwyqP-jI6woaJ8CMHQ=='
# >>>>>>>>>>>>>>>>>>>>>>>
# charles
# bartowski
# chuk
# 136575550
# 38388127
# 204 97 street
# queens
# NY
# 11355
# 12
# 16
# 12
# pbx
# oprtr
# 21
# 840
# 3360
# 43680
# 6
# 0
# 3
# 0
# 12
# 3
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtcjZ7bpJqtxAXYpxxXIlP3vvSPd2X2QWnNoABBFrWf_WIc6ySwJtj-Ht-Fbv3A_hWryihcWJYHGT0LssL7RKzWnzVMdTm9WXEGU2wwyW4n_pXX-D5BBqUniQHyvSLuWcCwuOjI4bDEqUHa21M0nwAR0y5NulRRtIdpng2S0hunWh-mnIGtshDPeD8RX8fbDUhasSr9h1IlsR9O679ZLm5YDyzBNrsHJwsIh41ccOVPCVUFIQIG-VWhSffwoL1mzCR4'
# >>>>>>>>>>>>>>>>>>>>>>>
# jack
# bauer
# jbow
# 835908720
# 34278998
# 59 127 road
# bronx
# NY
# 10472
# 7
# 13
# 17
# acct
# *cntrller
# 28
# >>>>>>>>>>>>>>>>>>>>>>>
# jim
# fallon
# jimy
# 141996232
# 05811197
# 242 29 street
# manhattan
# NY
# 10001
# 6
# 26
# 12
# hsk
# *deptmgr
# 26
# 1040
# 4160
# 54080
# 2
# 4
# 3
# 0
# 5
# 10
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtcebOUBV1EwDkGbfygl6oRuoHfueEC9-RFLSn6SP8QxU4QyGwWz4Fzjv3O0wW2Rx1NcSWpDlAV7RrCyITnVZZF1MbyvfaqXi_dm0JdrZEXTdpT1fqlZPaf17ONJhhtX7RHRN02pq1T9WqZM3CBaVswPsRFjGgskDj2P6o-BArfbaGc6nGu6EoBpbCcR1gYoXQgw84sbLUvpo1g1wYGhWfNDTWxbnETVSdXMrpWBQIszHV-6qgY3P79GDKrWdY5cL_k'
# >>>>>>>>>>>>>>>>>>>>>>>
# conan
# brian
# cone
# 537982748
# 34542041
# 4 38 avenue
# bronx
# NY
# 10472
# 5
# 20
# 17
# FD
# drmn
# 23
# 920
# 3680
# 47840
# 1
# 5
# 2
# 1
# 1
# 14
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltdxjy3W4LqOmVrq1jav7_b-P2ciiGumnJClssFIAslZN4f-TF1t-hoedWUltIHd9IVa3jDgQbjx808TS6aN8Xn5dmFY6A-fX9sj5trA5ZrNu1WE8oFFV0OCRkGVuKWgovh02nhyxhySiey0fmphMR16YNncDvgXWksFr1qYlE11sFn3NwpH1H9EKCtBDiVYk7zLNXUmbmPzvm514f4lzMGF8hkj4np1JzYraWvUh-atGZJMTuZz8Nxj8B9YaQcBp_B'
# >>>>>>>>>>>>>>>>>>>>>>>
# adam
# driver
# sith
# 325727640
# 08862410
# 252 137 street
# queens
# NY
# 11355
# 6
# 23
# 19
# eng
# *deptmgr
# 21
# 840
# 3360
# 43680
# 3
# 3
# 2
# 1
# 10
# 5
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdNLh0UqUl4G0lgIfcc_RBm0J-2lc_nRZ2Y2k3nW4Q6b77Q7V_Z9-44fhHRy12TVb4tWUxGEEw38VrmU5b7E4zb_Fxnm3Io5QpgC4PwnSuBgFFwOh03Yc3yKMZ8MmIk8yZ_6u0_2qhcd5AeMcgwixYSIsUgraFu2Zl-eYXTJ9Cu5IbRT9mOYovNBZo7wKfE9QnmcH3mfWNRsiJ_4kOrKmMKKA0vFvZQtDGd6u3mzazcKCPTv_iNkuGVWjpKlobkuaZ'
# >>>>>>>>>>>>>>>>>>>>>>>
# daisy
# ridley
# drid
# 896674848
# 13275990
# 215 17 street
# queens
# NY
# 11354
# 7
# 8
# 18
# FD
# drmn
# 29
# 1160
# 4640
# 60320
# 4
# 2
# 2
# 1
# 11
# 4
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdfuctW183rWkT4SqPtjHY7TKLotjew3Y9aJVuusHCFMTFH3P_4-BB8MCAtgDty2vXoS5WbIUpRjbheHpxImxHEX1Sr88oyxy-ee_KJNgOToVrla_-BptNq5sBEycL8qfoDW7L8pr1Whj03rsgh30wfz5Y6E-gDeMoxKSl8Z0nMkSvkCxTx-uX8Ny4D0KP5q0hw9_vVwqUGINs6Exd4n8sn2mehm_sCV1WlLSf5gP5hs6YOoL-AzwLxGgmooGUW6Rw'
# >>>>>>>>>>>>>>>>>>>>>>>
# alec
# baldwin
# bald
# 225774247
# 13119983
# 52 128 street
# bronx
# NY
# 10461
# 1
# 20
# 6
# sle
# *deptmgr
# 17
# 680
# 2720
# 35360
# 1
# 5
# 0
# 3
# 4
# 11
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdtHSJdx68QzyCeiDvb8v25QOTdRbwk2N7VkRKUzxLed6S7zziU8nkdAvY9zULDKdfgm4i1VA84ik55mpSi4L_cqQVM0aC0jE9hhYJ3MkRuMJZ58sl42gySPIad-UHB7Y_DzE9ODgGoiajSLMEmTbPgdXIrt1978XYM1qov5lhIZFc9f_ZBNr0jD5fIc4KyWkKg2X4JeX_UfePAwkrxzM0U_i_IRhtVFFWOxYft63ihTLXWTMB0o4gi51lW1_IvoAc'
# >>>>>>>>>>>>>>>>>>>>>>>
# steff
# tuan
# stef
# 717102157
# 32405019
# 185 40 road
# queens
# NY
# 11355
# 11
# 28
# 4
# eng
# *adeptmgr
# 25
# 1000
# 4000
# 52000
# 3
# 3
# 0
# 3
# 11
# 4
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltdk2gPw3T4i9HHPLL5sop0--kPFRO5jX2rs5gB0_kfXWOblDcQFO2WbqJSL1GI-MD0eOEyHQkYNtbWkLXkZF1S5uO7PsZD1nDVONnkyuz7f2WBV-PnpUNOqYmuSqxrb9L7e1KXquM5hOiGBr9m__jccxP2R0pN1PtnHHE-ft6dSg2zC0-QNOTYukmzeZpkPFzNkkHsa6D4ueOIANjAS24knSyO1m7Oo2VdIs3yexk033i8en2TeJ6fbo5I7lDIbr42zf5nhxWnhBDE4CP9rQsKTg=='
# >>>>>>>>>>>>>>>>>>>>>>>
# chris
# rudolf
# crud
# 376710902
# 34545385
# 237 123 street
# brooklyn
# NY
# 11217
# 9
# 17
# 7
# hsk
# hskper
# 28
# 1120
# 4480
# 58240
# 6
# 0
# 1
# 2
# 13
# 2
#
# files created!
# b'gAAAAABf0Ltdkov5Wggi-LIyjBVdKeMGxqkFjI4_ODEeG74nnc_Oegr-OWEjxgvxhgWcgjqNz5H06iXi876jqfxdr6oylDdI1k58J5jYvZ3StlSPzSaNViOjXYHgwMAzSqrAcI_mLN-LaZQDdeeFO0zgnTHWzw2SV3GSGxaPxhlYwpkBSCnBge8Z9qbxkMCkX4PwrwuEADfhSE6pi2FQgIeQO6eUW2l7_g67h7L3tk2mIQm9bxPNzJZxmeDwkdzfDVh6M11sVj9X'
# >>>>>>>>>>>>>>>>>>>>>>>
# peter
# camp
# gunn
# 626889437
# 22993042
# 151 64 road
# bronx
# NY
# 10462
# 7
# 25
# 19
# acct
# *asscntrller
# 18
# 720
# 2880
# 37440
# 2
# 4
# 3
# 0
# 15
# 0
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltd2VWMGd_7c1w7kQYLggtd2Dy5r_LJiOumhTlzPHi0ddRCnJJmD49u2urhMgkvQX6Di0H4vy3Wfv8vmoMiLXVl4qAEItbM61tmxjaextjKigFxb1i_sIDfaJVBZBBu8jtxRIEtvyjOVXBwZ5oOsRJ4GxdSSiDHGYheo6RONYKJWx1lAKg7ycJv20jx99yRpoFJNr683olviozb6SQlu2HQ97IgbsaI1NKBKq68DIFRgvTSGyBiaOuAfdCQLufH1biJ'
# >>>>>>>>>>>>>>>>>>>>>>>
# justine
# dean
# jusd
# 931911947
# 07072843
# 186 99 street
# queens
# NY
# 11357
# 7
# 24
# 14
# hsk
# hseman
# 23
# 920
# 3680
# 47840
# 5
# 1
# 3
# 0
# 15
# 0
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdfSU2v5FFA_BUITjtzzpDw6oVKzRkZo3IJab7sqdDmoc5QZ1t6QDlAUW6Gmxtx-IopiQZLhWc1Ki9chxHeQxEuImRKg3X9btKn-UZmSzhI0SrZ6Evw3ECI_evOz4alPZiyZfXYpEo6-i9q42U2xquGv_0sWEgIZt7axUN6pzBQyvajyLskbfWelxTK6449TLrd5-IRvBdwf1yPrR-7u5lDU55IDr3e4LwCRg3jNsbi7A01zN24vaNBMCpIgaOriHR'
# >>>>>>>>>>>>>>>>>>>>>>>
# mary
# bailey
# bail
# 937462521
# 02838503
# 34 124 street
# bronx
# NY
# 10462
# 10
# 3
# 13
# eng
# *deptsup
# 30
# 1200
# 4800
# 62400
# 2
# 4
# 3
# 0
# 11
# 4
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdWVbrrnsKPLJFNM9w6BifSk-h14SBQdihaBfvKH5ts0ebFCexx9RtAzu3qqBkeQoT0FWMKPEPn65hvi_ENsoJut4gC-Vsbwhgf6p4KVBKwc_Y-yuwOkVdvAi6idO6EAOSmUh4wLyYVIZeLaAziTPdhPhojeO5veet16WBrnv9KHItvYsj9qmr3b6y0NStmomth9tcBZicIHrgh6ep2d8VVeyFgRkxxwyI8v8Ptw6yyWS-gN02Lbsa_yqLYrMHG4aFYM-KJEHikw0nYTwu1siDug=='
# >>>>>>>>>>>>>>>>>>>>>>>
# marc
# singer
# funk
# 984935700
# 32296951
# 1 59 road
# staten island
# NY
# 10308
# 4
# 11
# 15
# hsk
# *deptmgr
# 23
# 920
# 3680
# 47840
# 1
# 5
# 3
# 0
# 7
# 8
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltd5FzvTJhmZTMK-l3cVCE8zYqaunJjRfsUSLT1RsN-EGATKhl6z_BS9KIYAGPQlSsICiXpm-VubCpuevU4Z9OI2SU9yyXKHT-cqAZRnU_M8xoVObFYhdrHi3EJ3rByR9PhZklbS5HyiUlIy6yaRGG_1ezMW_MUpJE7arCWaUJzreOtb2rFyYfAs8FZGDkp2Y2r9h7GR9BTOIdOCSvrpyu6MMKHICCXOB33CaNM9WRYiCXCC8_pgQgXs2FQo2GIVNQKkNtgj1Q-AQl9SSfQ9SeELQ=='
# >>>>>>>>>>>>>>>>>>>>>>>
# franco
# franus
# fran
# 707195002
# 04519288
# 298 52 avenue
# brooklyn
# NY
# 11215
# 12
# 26
# 15
# acct
# *asscntrller
# 30
# 1200
# 4800
# 62400
# 1
# 5
# 0
# 3
# 15
# 0
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdE7fftfZPqtM1PKXdez-DGeUlAuvPLEVDYYhp7I4f-gv5kdnPCTfUy0hqwleqKg7wmSNKN5QrXdpfVCzrtPx-rnUqUlNgHBIaed8NLlWRbPr0Bh_PSatHlnHpvsT_XpnNI2xxQ0RmXYm-qTF5exrYdPqmFdnp3LEvlEZ6mLrvBwZS0L2xV_w2YmEpBSII3afseWADFp3hqO7NBRhmGcIFU7Rcc9SSyNesO481QSI_JylZY3z87zghtxODEPGB3jesMnPsrYP3hu8yonaXMMOA-A=='
# >>>>>>>>>>>>>>>>>>>>>>>
# chris
# velez
# slam
# 475583166
# 09858043
# 246 7 road
# staten island
# NY
# 10308
# 4
# 3
# 14
# hsk
# *deptsup
# 18
# 720
# 2880
# 37440
# 6
# 0
# 1
# 2
# 7
# 8
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltdg4PgocYpCwSEv8KNtI01Vzvx_QTMtZymM-mH_YgcFwLkl2FrBN2fFiH1QTfxx3Oo0cAoYX6ralwYQTd9Yafg57WepRmxFhfFHgwOpvt8gcg7bIJXqae1R0QOVVGaewqVGBzclauw4ySAGwMEb45qT0-fkLqJoDrN4jfAYOdU2yd1BRYZQjYbRH2wA3I4ysgrVPs55yZyJCFq7GEBmDEQfsHUdrOf-hVeNOrv7CzPavjPnHKZ_0iQxSWfrLO2L53p'
# >>>>>>>>>>>>>>>>>>>>>>>
# jose
# quizon
# chic
# 806248927
# 23968159
# 80 119 road
# queens
# NY
# 11358
# 3
# 18
# 18
# pbx
# *deptsup
# 26
# 1040
# 4160
# 54080
# 0
# 6
# 2
# 1
# 5
# 10
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdTr0D0-MIiT8jKvmQ8qWglYoYKC4Iz16-G4T1Ug_YYLKd_a2YbbYRqmi07Ud3gsYa5BkjuAf04lZ2jqrrugs_2E5TohhNU6zFWAhqQs6QAfUIl9KocHWk0jxlU1jU_jI0ivBlhg5lsuc8QfM0FqG0QXO2-v3YwTJaz-oLdUiFR66Iapw3h-A4Y5R-GMuKO8x8AaxXw46KDMKuNioP9XHlhb1_UQNNWaQDRWbNyDMFabYizyU2ThjWHysdEXtsVLfc'
# >>>>>>>>>>>>>>>>>>>>>>>
# jumpa
# smith
# jusm
# 281630133
# 18159494
# 10 13 avenue
# queens
# NY
# 11355
# 6
# 13
# 19
# pbx
# *adeptmgr
# 19
# 760
# 3040
# 39520
# 5
# 1
# 3
# 0
# 0
# 15
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltd4QvsAdZtHRYqnIrwM8Bkjr71KJN05od4R-PpqLJRrmN1AHaKNOdKauClqkKLTqCfUI8HEHD9pM3Iys0KldqsmpDBsAMoBtUom2pCNR3D1ppy0xfZVRuud3HzrC6E6BdoOyR_moTqOZvnDDqdcyzrML1n7TQIacXhMuovCzcm3z65i2l7imx1WJocWJx-1b4840Mra1OI4wJ3WSy45X1JGS-5QXmbfvyyFV7R8ym9LFhJr0mpx1oCOC8XYXjJNYJR3jEOmZ6UGHLOsecOf6rDyw=='
# >>>>>>>>>>>>>>>>>>>>>>>
# jumpa
# jones
# jujo
# 822803952
# 17225889
# 84 21 avenue
# manhattan
# NY
# 10011
# 7
# 20
# 14
# sle
# *adeptmgr
# 22
# 880
# 3520
# 45760
# 5
# 1
# 1
# 2
# 9
# 6
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdzRYdsMwe5VIqO1eQHSZJH1QKNoy9bF3D6eZwTnLJH87jb2k9QGviAdYzUA9j4umVnvdt2UVj0n_3kVFxPMbPYg41csAk5YEqtOV8Vb3jtQRktm5LLei5gNZPuubKbPkMWAn-9PUK2ljRbT9JwpYYPMYJTjfsaLYbRAkhqG7w1qaQSq6Vskf4WUeagZvBc1NSA-vP9oA2n7QrnOv7IyHxGiYvfpB_-sAKDr2jcS3OmvigNS33IDADYLm48yiEpf_p7uDf4Ks5A8chMTee5Bf89g=='
# >>>>>>>>>>>>>>>>>>>>>>>
# thavone
# pengpang
# peng
# 921573437
# 06005624
# 78 16 street
# brooklyn
# NY
# 11231
# 12
# 18
# 6
# FD
# ntaud
# 20
# 800
# 3200
# 41600
# 2
# 4
# 1
# 2
# 11
# 4
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdgShWp56LODafExMD1n9AM_31QMBFWldJfi2DGC2LCMIxt-muqsywOC8VnTj4XYCuFva2H2VBGrann_v5Sna9eO3CCrOo6LwDs3Nqhod5Rya82-JTFtI06ihg40B7ol7dGUqWISaLgqUGKxl4kg0G34si_pQq45Wkb8INfCMzxXJKYh_WOIrwHrkAKdq4UsmfrJqbAY2kRRPu6N9Usc3iXe-N2f1xaleRvQFe3Us1WTosM1u18_V2wKMNO0VNBckPVkCySpDXj8H_qNEHcJxIuw=='
# >>>>>>>>>>>>>>>>>>>>>>>
# paul
# singh
# psin
# 505954471
# 35878312
# 240 120 avenue
# manhattan
# NY
# 10011
# 4
# 3
# 18
# hsk
# *deptsup
# 26
# 1040
# 4160
# 54080
# 2
# 4
# 1
# 2
# 4
# 11
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltdbjpj1_IE8_QK7pb9S5stXhU_dok9acFBk63QxDfsLA24bmdOuq5ELcaGoxvPpPwdrBJIll1MmYWEYbxPy3aiHg3sbyBbd0T0bg9N99XGmE9n4DMwFFWq37rL-ushmVliAc3GRLBP_r_UamvPw2abBfmJu9NZRffbEIhgKsXwl63QDG4WTQCR7nMNcaMHd5eaa2rIsWi-GneOahCEVLTXE2G_fmkd6mMYjAMg-EnFE-DL_U2VRyKnwbfvGPgZjgIV1xmqvwD5OqoNhZqAC338YA=='
# >>>>>>>>>>>>>>>>>>>>>>>
# jerry
# springer
# jspr
# 796712068
# 35112746
# 105 78 avenue
# manhattan
# NY
# 10018
# 11
# 18
# 16
# pbx
# *deptsup
# 18
# 720
# 2880
# 37440
# 6
# 0
# 3
# 0
# 3
# 12
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtdetzpH4CjwXkNF3hwPD-HpUD2qkur0a1HaV8kBcSIq0h2FZaWYou5YcEKKEGpxVnGMp8YlXrm7smXtpky1b4KbjOmZ_VIq8iliBTo5cu1hbwszJcFvjc5u_3xBixYZVfX22jpX8Lav5391R72NrA5wqQPBMgeuVWn4Ib10WmoEOpOV29pMOI8JRlPFpJyM37A4xgP4feQttyDR1IxYpqayE3ImMDVC35fR7FYPm-LAKP_H3na7rD7zNGW07UC9q6p'
# >>>>>>>>>>>>>>>>>>>>>>>
# andrew
# jones
# anjo
# 126409711
# 15351594
# 104 8 road
# queens
# NY
# 11358
# 12
# 2
# 9
# hsk
# *deptmgr
# 28
# 1120
# 4480
# 58240
# 2
# 4
# 2
# 1
# 2
# 13
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0Ltesw5mr-qIpeL7gSd35QcXk56JAVYxZRXO15l4yilMTsbrY4xaKrSnGf3bSe5E5YiPz26_4Y6kPnt2EgENaI9EpQUoOGt8gyOxZcVy4otkOVgYFgaF7UUvKf5AewoA6dGyV1dvOjHmWEuLZSJfI1zaN-8XK6MEornEzsrYTJxogwtqaLsbqHLywd3yjJ5T39DohLbaykOFAvIFgLUqKdebzaP2NLWoTKjCB7THj_9i8ESjuqZo-W7jhgYqbX64sAUYAhqxNivhPvdbk9U_CGK0Kw=='
# >>>>>>>>>>>>>>>>>>>>>>>
# cole
# henderson
# heno
# 951339060
# 22711443
# 101 59 road
# staten island
# NY
# 10307
# 2
# 25
# 5
# sle
# *deptsup
# 30
# 1200
# 4800
# 62400
# 2
# 4
# 1
# 2
# 7
# 8
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LteF8my3PYVftzpjUh8vvrkR-gvQZGtZe2-fk3W5fSlnZ_QnGz7vRy71sStJ95MWgaTzTyDZk3LTakJcic-LbbhBM-_nGUnvC9IrrI_8uaGmINk2Yj8MMBj8p09IFYjSEgzBHV2Dbu-OtLWUj3RrTachdxEnKrLZjnLuNM40C6-Ih7IJizUBTkywzSmLuiy3HO-HWX9TPYTbe11nr-WYCbnjs6Nvr9v9RIiiJD14AXTpcKT64NTwwrB55wRPIPzR3mKoGGM_ZFzSWbbBKrxXBDt0g=='
# >>>>>>>>>>>>>>>>>>>>>>>
# george
# st.pierre
# gstp
# 782885778
# 26025132
# 255 96 road
# queens
# NY
# 11354
# 7
# 19
# 7
# pbx
# *deptmgr
# 20
# 800
# 3200
# 41600
# 0
# 6
# 3
# 0
# 15
# 0
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LteXSwh5q-xLuVeQttGBSdfV5Y6Phg-RRzF34tUAT865M8NiSkuAjSLmjNa6M3HeK-IDYQBS1GCXaL7xAPXy7oroIVcynKpqcBBfP6QQhB-mGStoDKush4qCv9NPCpLdCQQlymM_8heCNRUPufKYUK4lVoBZPjHMRS7dcq873vldtMSFnoiABCRB9SNn04rZKqzavqHUa7oHSyLHMnC1dXrSuDZxxx1sv6ByNheLHarVyBLy8tF2t3hHU1ZtsBil0EH'
# >>>>>>>>>>>>>>>>>>>>>>>
# luc
# petty
# lpet
# 752179787
# 01555999
# 186 6 road
# brooklyn
# NY
# 11215
# 10
# 7
# 17
# eng
# engnr
# 30
# 1200
# 4800
# 62400
# 5
# 1
# 2
# 1
# 2
# 13
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LterTmQZOC0hoN401K2K7RsXHeK0e5_VclIG5ak47hVLiTNMYCs3Ej3Q1BTrTFsCRQRbX_9Pni4xo00eJSEf6v7PZmb5gKPb3IM_NxzhfjHziOU6fDa3HNecNXKY-Q2X2uCuQoX1oeagBOI_x62YGZGRINFWuXFbxFfrGEcbqU67pqwHrayDjBndvlOiQmebbsmuAZg5VQslktMVOcMds-3b5YM58k4MkeUbS7b-_0DRR9iSuJ0f-SrAi1Y2pzUVl9F'
# >>>>>>>>>>>>>>>>>>>>>>>
# todd
# bryant
# tbry
# 871859478
# 08786480
# 134 10 avenue
# bronx
# NY
# 10472
# 7
# 12
# 12
# hsk
# *deptsup
# 17
# 680
# 2720
# 35360
# 5
# 1
# 0
# 3
# 9
# 6
#
# files created!
# b'M0T9DUR6y6mb9XXhbXU22gUjxVO-rGnVUIEjP6iWi-A='
# b'gAAAAABf0LtetdxaRcapoHsAbatv7jLxW1kla1C1Q9V1KorJXfZgYWbi7v2hHZFOaFZds7tosvhkxzzDj2Ii4-Slx7htuillEbTcu1FwLZmF_gmM5n4nihf4tXzlI2yHpZLNv4LQ46ufivSvA_Va3NbGgL8nyhVdkTBP9mgC7suFlDg_-TXnXqoVaS7Uw9UuyezFbK5bt0J7odMLMCKJS1-8n8Vuq9sp615OOxk1nQa3fLD_um4yQwcBDOTTFG_u-h0YEEzQcsVb8S82pJW-mSR0jfr7ubYylg=='
# >>>>>>>>>>>>>>>>>>>>>>>
# robin
# banger
# bang
# 597466508
# 13065708
# 47 124 street
# staten island
# NY
# 10307
# 8
# 20
# 11
# hsk
# *deptmgr
# 19
# 760
# 3040
# 39520
# 1
# 5
# 3
# 0
# 12
# 3

# %%
import os
def demoend():
    fnames=['00','jasonbourne','sarawalker','johncasey','charlesbartowski','jackbauer','tonyroop','gregcosent','macgregorjones','jalenhurts','nicksaban','paulbryant','jimfallon','conanbrian','adamdriver','daisyridley','alecbaldwin','stefftuan','chrisrudolf','kyloren','michaelokeyo','michaeldonaldson','petercamp','justinedean','marybailey','marcsinger','francofranus','chrisvelez','josequizon','jumpasmith','jumpajones','thavonepengpang','paulsingh','jerryspringer','andrewjones','colehenderson','georgest.pierre','lucpetty','toddbryant','robinbanger']
    for x in range (len(fnames)):
        if os.path.exists(f'testdocs/{fnames[x]}D.night'):
            os.remove(f'testdocs/{fnames[x]}D.night')
        elif os.path.exists(f'testdocs/{fnames[x]}Dsickdates.night'):
            os.remove(f'testdocs/{fnames[x]}Dsickdates.night')
        elif os.path.exists(f'testdocs/{fnames[x]}Dpersdates.night'):
            os.remove(f'testdocs/{fnames[x]}Dpersdates.night')
        elif os.path.exists(f'testdocs/{fnames[x]}Dvacdates.night'):
            os.remove(f'testdocs/{fnames[x]}Dvacdates.night')
        else:
            print('no file no delete!')
demoend()
# Out:
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
# no file no delete!
