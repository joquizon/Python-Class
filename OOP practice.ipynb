# %%
dataentered=[]

def newEmp():
    firstname= input("first name: ")
    lastname= input("last name: ")
    ssn= input("ssn: ")
    telno= input("tel no: ")
    email= input("email: ")
    streetaddress= input("street address: ")
    city= input("city: ")
    state= input("state: ")
    zipcode= input("zipcode: ")
    salary= input("salary: ")
    dept= input("dept: ")
    manager= input("manager: ")
    position= input("position: ")
    insurance= input("insurance: ")
    transitpay= input("transitpay: ")
    fouronek= input("401k: ")
    vacationtime= input("vacation time: ")
    personaltime= input("personal time: ")
    sicktime= input("sick time: ")
    
    dataentered.append(firstname)
    dataentered.append(lastname)
    dataentered.append(ssn)
    dataentered.append(telno)
    dataentered.append(email)
    dataentered.append(streetaddress)
    dataentered.append(city)
    dataentered.append(state)
    dataentered.append(zipcode)
    dataentered.append(salary)
    dataentered.append(dept)
    dataentered.append(manager)
    dataentered.append(position)
    dataentered.append(insurance)
    dataentered.append(transitpay)
    dataentered.append(fouronek)
    dataentered.append(vacationtime)
    dataentered.append(personaltime)
    dataentered.append(sicktime)
    
    for x in range (len(dataentered)):
        print(f"{x} {dataentered[x]}")
        
def passwordcheck():
    password = input("password: ")
    if password == '0908':
            print('youre in!')
    else:
        print('wrong!wrong!')
        passwordcheck()
        
passwordcheck()

def employeesearch():
    searchname = input("type first and last name with no space in between:")

def modeset():
    mission = input("1 for entry or 2 for output: ")
    if mission== '1':
        print("A new employee! coo'coo :)")
        newEmp()
    else:
        pass
        #run search function for editing employee info
modeset()



# empFname=dataentered[0]
# empLname =dataentered[1]
# socno =dataentered[2]
# contactTel =dataentered[3]
# contactEmail =dataentered[4]
# contactAdd1 =dataentered[5]
# contactAddCity =dataentered[6]
# contactAddSt =dataentered[7]
# contactAddZip =dataentered[8]
# empSal =dataentered[9]
# dept =dataentered[10]
# mgr =dataentered[11]
# posit =dataentered[12]
# healthIns =dataentered[13]
# transitpay =dataentered[14]
# four1k =dataentered[15]
# vacationtime =dataentered[16]
# personaltime =dataentered[17]
# sicktime =dataentered[18]



        
def verifier():
    verify = input('enter (y) to confirm data or (n) to edit data: ')
    if verify == 'y':
        print('yayus!')
    elif verify =='n':
        def subverify1():
            while True:
                try:
                    choose = int(input('Which line should we edit: '))
                    if choose <= (len(dataentered)-1) and choose >= 0:
                        more = input('any others y or n: ')
                        while True:
                            if more == 'y':
                                print('ok cool, but let us fix this line first')
                                print(f'{dataentered[choose]} will now be edited. Enter new Info below')
                                newentry = input('correction: ')
                                dataentered[choose] = newentry
                                print(f'Info on line {choose} has now been changed to {newentry}.')
                                choose = int(input('Which line should we edit: '))
                                more = input('any others y or n: ')

                            elif more == "n":
                                print("ok great let's edit!")
                                print(f'{dataentered[choose]} will now be edited. Enter new Info below')
                                newentry = input('correction: ')
                                dataentered[choose] = newentry
                                print(f'Info on line {choose} has now been changed to {newentry}.')
                                for x in range (len(dataentered)):
                                    print(f"{x} ... {dataentered[x]}")
                                verifier()
                                break
                            else:
                                print("C'mon dude! y or n")
                                more = input('any others y or n: ')
                    else:
                        print('choose a line')
                        subverify1()
                        break
                except:
                    print("input has to be a number")
                    subverify1()
                    break
                finally:
                    break
        subverify1()   
    else:
        print('y or n dude...wtf :(') 
        verifier()
verifier()
    
    
    
    
#     each item item on list will be numbered and user will choose number to edit then new edit will replace item on list
    
    
    
    #vac-,pers-,sick- Count inputs will be sent to vac-,pers-,sick- CountLists to be added up. lists will keep count of
    #how many have been days / hrs have been taken

#     vacCountList = []
    # vacTaken = sum(vacCountList)
    # vactimeLeft = vacationtime - vacTaken
    # vacDate = input("vacation date start: ")
    # vacCount = input("no. of days taken from " + vacDate + " (not including regular days off):")

#     persCountList = []
    # persTaken = sum(persCountList)
    # perstimeLeft = personaltime - persTaken
    # persDate = input("personal day taken date : ")
    # persCount = input("no. of days taken from " + persDate + " (not including regular days off):")
#     sickCountList = []
    # sickTaken = sum(sickCountList)
    # sicktimeLeft = sicktime - sickTaken
    # sickDate = input("sick day taken date : ")
    # sickCount = input("no. of days taken from " + sickDate + ":")
empFname=dataentered[0]
empLname =dataentered[1]
fullname = empFname + empLname
socno =dataentered[2]
contactTel =dataentered[3]
contactEmail =dataentered[4]
contactAdd1 =dataentered[5]
contactAddCity =dataentered[6]
contactAddSt =dataentered[7]
contactAddZip =dataentered[8]
empAddress = contactAdd1 + contactAddCity + contactAddSt + contactAddZip
empSal =dataentered[9]
dept =dataentered[10]
mgr =dataentered[11]
posit =dataentered[12]
healthIns =dataentered[13]
transitpay =dataentered[14]
four1k =dataentered[15]
vacationtime =dataentered[16]
personaltime =dataentered[17]
sicktime =dataentered[18]

class Employee:
    pass
    def __init__(self,first,last,social,contel,conemail,fulladdress,salary,dept,manager,position,insure,transit,f401k,vac,pers,sick):
        self.first=first
        self.last=last
        self.social=social
        self.contel=contel
        self.conemail=conemail
        self.fulladdress=fulladdress
        self.salary=salary
        self.dept=dept
        self.manager=manager
        self.position=position
        self.insure=insure
        self.transit=transit
        self.f401k=f401k
        self.vac=vac
        self.pers=pers
        self.sick=sick
        self.workmail = first+'.'+last+'@themaritimehotel.com'
        workemail = self.workmail
        self.data = [first,last,social,contel,conemail,fulladdress,salary,dept,manager,position,insure,transit,f401k,vac,pers,sick,workemail]
        
        
#employeecreate() takes the inputs so the emplyee is instantiated in the class
def EmployeeCreate():
    globals()[empFname+empLname] = Employee(empFname,empLname,socno,contactTel,contactEmail,empAddress,empSal,dept,mgr,posit,healthIns,transitpay,four1k,vacationtime,personaltime,sicktime)
    

EmployeeCreate()

def datasave():
    import pickle
    globals()[empFname + empLname +'data'] = (globals()[empFname+empLname]).data
    print (globals()[empFname + empLname +'data'])
    pickle.dump((globals()[empFname + empLname +'data']),open('C:/Users/joseq/'+fullname+'.txt','wb'))
    print (f"{fullname}'s data has been saved!!!")

datasave()
# Out:
# password: 09
# wrong!wrong!
# password: 098
# wrong!wrong!
# password: 0908
# youre in!
# 1 for entry or 2 for output: 1
# A new employee! coo'coo :)
# first name: chico
# last name: quizon!!!xxx
# ssn: 422
# tel no: 917
# email: j@hotm.com
# street address: 7054 bway
# city: jax
# state: ny
# zipcode: 11372
# salary: 500000
# dept: fd
# manager: pq
# position: ntmgr
# insurance: united
# transitpay: y
# 401k: y
# vacation time: 21
# personal time: 6
# sick time: 6
# 0 chico
# 1 quizon!!!xxx
# 2 422
# 3 917
# 4 j@hotm.com
# 5 7054 bway
# 6 jax
# 7 ny
# 8 11372
# 9 500000
# 10 fd
# 11 pq
# 12 ntmgr
# 13 united
# 14 y
# 15 y
# 16 21
# 17 6
# 18 6
# enter (y) to confirm data or (n) to edit data: n
# Which line should we edit: 0
# any others y or n: y
# ok cool, but let us fix this line first
# chico will now be edited. Enter new Info below
# correction: josereginaldo
# Info on line 0 has now been changed to josereginaldo.
# Which line should we edit: 1
# any others y or n: n
# ok great let's edit!
# quizon!!!xxx will now be edited. Enter new Info below
# correction: Quizon
# Info on line 1 has now been changed to Quizon.
# 0 ... josereginaldo
# 1 ... Quizon
# 2 ... 422
# 3 ... 917
# 4 ... j@hotm.com
# 5 ... 7054 bway
# 6 ... jax
# 7 ... ny
# 8 ... 11372
# 9 ... 500000
# 10 ... fd
# 11 ... pq
# 12 ... ntmgr
# 13 ... united
# 14 ... y
# 15 ... y
# 16 ... 21
# 17 ... 6
# 18 ... 6
# enter (y) to confirm data or (n) to edit data: n
# Which line should we edit: ihuuhiuhh
# input has to be a number
# Which line should we edit: 6
# any others y or n: afaefa
# C'mon dude! y or n
# any others y or n: y
# ok cool, but let us fix this line first
# jax will now be edited. Enter new Info below
# correction: jackson Heights
# Info on line 6 has now been changed to jackson Heights.
# Which line should we edit:
# input has to be a number
# Which line should we edit:
# input has to be a number
# Which line should we edit: 4
# any others y or n: n
# ok great let's edit!
# j@hotm.com will now be edited. Enter new Info below
# correction: j@hotmail.com
# Info on line 4 has now been changed to j@hotmail.com.
# 0 ... josereginaldo
# 1 ... Quizon
# 2 ... 422
# 3 ... 917
# 4 ... j@hotmail.com
# 5 ... 7054 bway
# 6 ... jackson Heights
# 7 ... ny
# 8 ... 11372
# 9 ... 500000
# 10 ... fd
# 11 ... pq
# 12 ... ntmgr
# 13 ... united
# 14 ... y
# 15 ... y
# 16 ... 21
# 17 ... 6
# 18 ... 6
# enter (y) to confirm data or (n) to edit data: y
# yayus!
# ['josereginaldo', 'Quizon', '422', '917', 'j@hotmail.com', '7054 bwayjackson Heightsny11372', '500000', 'fd', 'pq', 'ntmgr', 'united', 'y', 'y', '21', '6', '6', 'josereginaldo.Quizon@themaritimehotel.com']
# ['josereginaldo', 'Quizon', '422', '917', 'j@hotmail.com', '7054 bwayjackson Heightsny11372', '500000', 'fd', 'pq', 'ntmgr', 'united', 'y', 'y', '21', '6', '6', 'josereginaldo.Quizon@themaritimehotel.com']
# josereginaldoQuizon's data has been saved!!!

# %%
open("fullname.txt",'r')dcd
c
# Out:
# <_io.TextIOWrapper name='fullname.txt' mode='r' encoding='cp1252'>

# %%
open('josechicoquizon.txt','r')
# Out:
# <_io.TextIOWrapper name='josechicoquizon.txt' mode='r' encoding='cp1252'>

# %%
d =[]

def entrytest():
    a1='vv1'
    a2='vv2'
    a3='vv3'
    d.append(a1)
    d.append(a2)
    d.append(a3)
    print(d)
    print(len(d))
    for x in range (len(d)):
        print(f"{x} ... {d[x]}")
    def verifier():
        verify = input('good or nah: ')
        if verify == 'good':
            print('yayus!')
        else:
            def subverify1():
                while True:
                    try:
                        choose = int(input('Which line should we edit: '))
                        if choose <= (len(d)-1) and choose >= 0:
                            while True:
                                more = input('any others y or n: ')
                                if more == 'y':
                                    print('ok cool, but let us fix this line first')
                                    print(f'{d[choose]} will now be edited. Enter new Info below')
                                    newentry = input('correction: ')
                                    d[choose] = newentry
                                    print(f'Info on line {choose} has now been changed to {newentry}.')
                                    choose = int(input('Which line should we edit: '))

                                elif more == "n":
                                    print("ok great let's edit!")
                                    print(f'{d[choose]} will now be edited. Enter new Info below')
                                    newentry = input('correction: ')
                                    d[choose] = newentry
                                    print(f'Info on line {choose} has now been changed to {newentry}.')
                                    for x in range (len(d)):
                                        print(f"{x} ... {d[x]}")
                                    verifier()
                                    break
                                else:
                                    print("C'mon dude! y or n")
                        else:
                            print('choose a line')
                            subverify1()
                            break
                    except:
                        print("input has to be a number")
                        subverify1()
                        break
                    finally:
                        break
            subverify1()   
    verifier()
entrytest()
# Out:
# ['vv1', 'vv2', 'vv3']
# 3
# 0 ... vv1
# 1 ... vv2
# 2 ... vv3
# good or nah: n
# Which line should we edit: sadfaf
# input has to be a number
# Which line should we edit: 2
# any others y or n: y
# ok cool, but let us fix this line first
# vv3 will now be edited. Enter new Info below
# correction: fafafefaf
# Info on line 2 has now been changed to fafafefaf.

# %%
for x in range (len(d)):
    print(f"{x}{d[x]}")
# Out:
# 0grgrgr
# 1vv2
# 2aervdsvvvzs

# %%
x = len(d)
print(x)
